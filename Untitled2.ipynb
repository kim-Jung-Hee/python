# %% [markdown]
# <a href="https://colab.research.google.com/github/kim-Jung-Hee/python/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#202200906 김정희
# 과제 2번
num=int(input('숫자를 입력하세요:'))
i=1

if num <=30 :
  while i<=num:
    if i==1:
      print(i)
      i+=1
    elif i>1: 
     print('*'*(i-1),end='')
     print(i)
     i+=1
    
else: 
  print('숫자가 너무 커요. 30 이하의 숫자를 입력하세요.')
# Out:
# 숫자를 입력하세요:6
# 1
# *2
# **3
# ***4
# ****5
# *****6

# %%
# 202200906 김정희
# 과제 1번- 0을 입력했을 경우

count=1 
list=[]

num=int(input('자연수 한 개를 입력하세요:'))
list.append(num)
  
while count<=99:
  num=int(input('계속 입력을 원하시면, 자연수 한 가를 압력하시고, 아니라면 0을 입력하세요.:'))
  count+=1
  if count==100 and ex_num!=0:
    print('이제 그만하세요.벌써 100개를 입력했어요.')
  elif ex_num==0:
    print('그만 입력다니다,')
    break
  list.append(ex_num)

  t=0

  for i in range(0,len(list)-1):
    if list[i] > list[i+1]:
      t=list[i]
      list[i]=list[i+1]
      list[i+1]=t
    for j in range(0,len(list)-1):
     if list[j] > list[j+1]:
        t=list[j]
        list[j]=list[j+1]
        list[j+1]=t

print('당신이 입력한 숫자를 큰 것부터 순서대로 말한다면 아래와 같습니다.',list)
# Out:
# 자연수 한 개를 입력하세요:4
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:7
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:2
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:0
# 그만 입력합니다.
# 당신이 입력한 숫자를 큰 것부터 순서대로 말한다면 아래와 같습니다. [2, 4, 7]

# %%
#202200906 김정희
# 과제 1번-100개 해보기

count=1
list=[]

num=int(input('자연수 한 개를 입력하세요:'))
list.append(num)

while count<=99 :
  ex_num=int(input('계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:'))
  count+=1
  if count==100 and ex_num!=0:
    print('이제 그만하세요. 벌써 100개를 입력했어요.')
  elif ex_num==0:
    print('그만 입력합니다.')
    break
  list.append(ex_num)
  
  num=0

  for i in range(0,len(list)-1):
    if list[i] > list[i+1]:
      num=list[i]
      list[i]=list[i+1]
      list[i+1]=num
    for j in range(0,len(list)-1):
     if list[j] > list[j+1]:
        num=list[j]
        list[j]=list[j+1]
        list[j+1]=num 

print('당신이 입력한 숫자를 큰 것부터 순서대로 말한다면 아래와 같습니다.',list)
# Out:
# 자연수 한 개를 입력하세요:5
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:12
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:67
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:9
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:4
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:3
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:6
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:11
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:17
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:18
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:56
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:9
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:78
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:23
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:26
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:45
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:48
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:16
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:18
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:43
# 계속 입력을 원하시면, 자연수 한 개를 입력하시고, 아니라면 0을 입력하세요:32
# ...

# %%
# sorted, sort를 사용하지 않는 방법 찾기

list=[0,13,9,4,8,5,5]
num=0

for i in range(0,len(list)-1):
  if list[i] > list[i+1]:
    num=list[i]
    list[i]=list[i+1]
    list[i+1]=num
  for j in range(0,len(list)-1):
   if list[j] > list[j+1]:
      num=list[j]
      list[j]=list[j+1]
      list[j+1]=num 
print(list)
# Out:
# [0, 4, 5, 5, 8, 9, 13]

# %%
# append, sorted 확인하기
list=[4,8,9,2,10]
list.append(5)
print(list)
list.sort()
print(list)
# Out:
# [5]
